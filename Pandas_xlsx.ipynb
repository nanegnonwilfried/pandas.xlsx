# %%
import pandas as pd
import numpy as np

# %%
# 1. Importez le fichier de données “coeur” dans dans votre notebook à l’aide de pandas et stockez le dans un objet appelé “data”.
data =pd.read_excel('Coeur.xlsx')
data
# Out:
#      AGE   SEXE  TDT    PAR  CHOLESTEROL  GAJ     ECG  FCMAX ANGINE  \
# 0     40  homme   AA  140.0        289.0    0  Normal    172    Non
# 1     49  femme  DNA  160.0        180.0    0  Normal    156    Non
# 2     37  homme   AA  130.0        283.0    0      ST     98    Non
# 3     48  femme  ASY  138.0        214.0    0  Normal    108    Oui
# 4     54  homme  DNA  150.0        195.0    0  Normal    122    Non
# ..   ...    ...  ...    ...          ...  ...     ...    ...    ...
# 913   45  homme   AT    NaN        264.0    0  Normal    132    Non
# 914   68  homme  ASY    NaN        193.0    1  Normal    141    Non
# 915   57  homme  ASY    NaN        131.0    0  Normal    115    Oui
# 916   57  femme   AA    NaN        236.0    0     LVH    174    Non
# 917   38  homme  DNA    NaN        175.0    0  Normal    173    Non
#
#      DEPRESSION      PENTE  CŒUR
# 0           0.0  Ascendant     0
# 1           1.0       Plat     1
# 2           0.0  Ascendant     0
# ...

# %%
# 2. Faites une copie de l’objet “data” dans un nouvel objet appelé “df”.
df=data

# %%
# 3. Affichez le type de l’objet “df”
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# 4. Affichez les 10 premières lignes de “df”
df.head(10)
# Out:
#    AGE   SEXE  TDT    PAR  CHOLESTEROL  GAJ     ECG  FCMAX ANGINE  DEPRESSION  \
# 0   40  homme   AA  140.0        289.0    0  Normal    172    Non         0.0
# 1   49  femme  DNA  160.0        180.0    0  Normal    156    Non         1.0
# 2   37  homme   AA  130.0        283.0    0      ST     98    Non         0.0
# 3   48  femme  ASY  138.0        214.0    0  Normal    108    Oui         1.5
# 4   54  homme  DNA  150.0        195.0    0  Normal    122    Non         0.0
# 5   39  homme  DNA  120.0        339.0    0  Normal    170    Non         0.0
# 6   45  femme   AA  130.0        237.0    0  Normal    170    Non         0.0
# 7   54  homme   AA  110.0        208.0    0  Normal    142    NaN         0.0
# 8   37  homme  ASY  140.0        207.0    0     NaN    130    Oui         1.5
# 9   48  femme   AA  120.0        284.0    0  Normal    120    Non         0.0
#
#        PENTE  CŒUR
# 0  Ascendant     0
# 1       Plat     1
# 2  Ascendant     0
# 3       Plat     1
# ...

# %%
# 5. Affichez les 10 dernières lignes de “df”
df.tail(10)
# Out:
#      AGE   SEXE  TDT    PAR  CHOLESTEROL  GAJ     ECG  FCMAX ANGINE  \
# 908   63  homme  ASY  140.0        187.0    0     LVH    144    Oui
# 909   63  femme  ASY  124.0        197.0    0  Normal    136    Oui
# 910   41  homme   AA  120.0        157.0    0  Normal    182    Non
# 911   59  homme  ASY  164.0        176.0    1     LVH     90    Non
# 912   57  femme  ASY  140.0        241.0    0  Normal    123    Oui
# 913   45  homme   AT    NaN        264.0    0  Normal    132    Non
# 914   68  homme  ASY    NaN        193.0    1  Normal    141    Non
# 915   57  homme  ASY    NaN        131.0    0  Normal    115    Oui
# 916   57  femme   AA    NaN        236.0    0     LVH    174    Non
# 917   38  homme  DNA    NaN        175.0    0  Normal    173    Non
#
#      DEPRESSION      PENTE  CŒUR
# 908         4.0  Ascendant     1
# 909         0.0       Plat     1
# 910         0.0  Ascendant     0
# 911         1.0       Plat     1
# 912         0.2       Plat     1
# ...

# %%
# 6. Affichez le nombre de lignes et de colonnes de “df”
df.shape
# Out:
# (918, 12)

# %%
# 7. Affichez le nombre de dimensions de “df”
df.ndim
# Out:
# 2

# %%
# 8. Affichez la liste des colonnes de “df”
df.columns
# Out:
# Index(['AGE', 'SEXE', 'TDT', 'PAR', 'CHOLESTEROL', 'GAJ', 'ECG', 'FCMAX',
#        'ANGINE', 'DEPRESSION', 'PENTE', 'CŒUR'],
#       dtype='object')

# %%
# 9. Affichez le type de chaque colonne de “df”
df.dtypes
# Out:
# AGE              int64
# SEXE            object
# TDT             object
# PAR            float64
# CHOLESTEROL    float64
# GAJ              int64
# ECG             object
# FCMAX            int64
# ANGINE          object
# DEPRESSION     float64
# PENTE           object
# CŒUR             int64
# dtype: object

# %%
# 10. Afficher les statistiques descriptives des variables qui sont dans “df”
df.describe()
# Out:
#               AGE         PAR  CHOLESTEROL         GAJ       FCMAX  \
# count  918.000000  913.000000   917.000000  918.000000  918.000000
# mean    53.510893  132.407448   198.823337    0.233115  136.809368
# std      9.432617   18.544767   109.441463    0.423046   25.460334
# min     28.000000    0.000000     0.000000    0.000000   60.000000
# 25%     47.000000  120.000000   173.000000    0.000000  120.000000
# 50%     54.000000  130.000000   223.000000    0.000000  138.000000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000
# max     77.000000  200.000000   603.000000    1.000000  202.000000
#
#        DEPRESSION        CŒUR
# count  918.000000  918.000000
# mean     0.887364    0.553377
# std      1.066570    0.497414
# min     -2.600000    0.000000
# 25%      0.000000    0.000000
# 50%      0.600000    1.000000
# 75%      1.500000    1.000000
# max      6.200000    1.000000

# %%
# 11. Afficher les 4 premières variables et les 10 premières lignes de “df”
print(df[['AGE','SEXE','TDT','PAR']].head(10))
# Out:
#    AGE   SEXE  TDT    PAR
# 0   40  homme   AA  140.0
# 1   49  femme  DNA  160.0
# 2   37  homme   AA  130.0
# 3   48  femme  ASY  138.0
# 4   54  homme  DNA  150.0
# 5   39  homme  DNA  120.0
# 6   45  femme   AA  130.0
# 7   54  homme   AA  110.0
# 8   37  homme  ASY  140.0
# 9   48  femme   AA  120.0

# %%
# 12. Afficher les personnes qui ont plus de 50 ans
df[df['AGE']>50]
# Out:
#      AGE   SEXE  TDT    PAR  CHOLESTEROL  GAJ     ECG  FCMAX ANGINE  \
# 4     54  homme  DNA  150.0        195.0    0  Normal    122    Non
# 7     54  homme   AA  110.0        208.0    0  Normal    142    NaN
# 11    58  homme   AA  136.0        164.0    0      ST     99    Oui
# 15    54  femme   AA  120.0        273.0    0  Normal    150    Non
# 18    60  homme  ASY  100.0        248.0    0     NaN    125    Non
# ..   ...    ...  ...    ...          ...  ...     ...    ...    ...
# 911   59  homme  ASY  164.0        176.0    1     LVH     90    Non
# 912   57  femme  ASY  140.0        241.0    0  Normal    123    Oui
# 914   68  homme  ASY    NaN        193.0    1  Normal    141    Non
# 915   57  homme  ASY    NaN        131.0    0  Normal    115    Oui
# 916   57  femme   AA    NaN        236.0    0     LVH    174    Non
#
#      DEPRESSION      PENTE  CŒUR
# 4           0.0  Ascendant     0
# 7           0.0  Ascendant     0
# 11          2.0       Plat     1
# ...

# %%
# 13. Afficher les personnes de plus de 50 ans de sexe féminin
df[(df['AGE']> 50) & (df['SEXE']=='femme')]
# Out:
#      AGE   SEXE  TDT    PAR  CHOLESTEROL  GAJ     ECG  FCMAX ANGINE  \
# 15    54  femme   AA  120.0        273.0    0  Normal    150    Non
# 28    53  femme   AA  113.0        468.0    0  Normal    127    Non
# 40    54  femme   AA  150.0        230.0    0  Normal    130    Non
# 41    54  femme  DNA  130.0        294.0    0      ST    100    Oui
# 54    52  femme  ASY  130.0        180.0    0  Normal    140    Oui
# ..   ...    ...  ...    ...          ...  ...     ...    ...    ...
# 901   58  femme  ASY  170.0        225.0    1     LVH    146    Oui
# 906   55  femme   AA  132.0        342.0    0  Normal    166    Non
# 909   63  femme  ASY  124.0        197.0    0  Normal    136    Oui
# 912   57  femme  ASY  140.0        241.0    0  Normal    123    Oui
# 916   57  femme   AA    NaN        236.0    0     LVH    174    Non
#
#      DEPRESSION      PENTE  CŒUR
# 15          1.5       Plat     0
# 28          0.0  Ascendant     0
# 40          0.0  Ascendant     0
# ...

# %%
# 14. Afficher les personnes de plus de 50 ans de sexe féminin qui ont une maladie cardiaque
df[(df['AGE']>50) & (df['SEXE']=='femme') & (df['CŒUR']==1) ]
# Out:
#      AGE   SEXE  TDT    PAR  CHOLESTEROL  GAJ     ECG  FCMAX ANGINE  \
# 41    54  femme  DNA  130.0        294.0    0      ST    100    Oui
# 117   59  femme  ASY  130.0        338.0    1      ST    130    Oui
# 123   58  femme   AA  180.0        393.0    0  Normal    110    Oui
# 144   56  femme   AA  120.0        279.0    0  Normal    150    Non
# 221   51  femme  ASY  160.0        303.0    0  Normal    150    Oui
# 303   62  femme  ASY  120.0          0.0    1      ST    123    Oui
# 305   51  femme  ASY  120.0          0.0    1  Normal    127    Oui
# 339   64  femme  ASY   95.0          0.0    1  Normal    145    Non
# 365   64  femme  ASY  200.0          0.0    0  Normal    140    Oui
# 375   73  femme  DNA  160.0          0.0    0      ST    121    Non
# 396   62  femme   AT  140.0          0.0    1  Normal    143    Non
# 415   66  femme  ASY  155.0          0.0    1  Normal     90    Non
# 495   64  femme  ASY  142.0        276.0    0  Normal    140    Oui
# ...

# %%
#15.Vérifier si une donnée est manquante
df.isna()
# Out:
#        AGE   SEXE    TDT    PAR  CHOLESTEROL    GAJ    ECG  FCMAX  ANGINE  \
# 0    False  False  False  False        False  False  False  False   False
# 1    False  False  False  False        False  False  False  False   False
# 2    False  False  False  False        False  False  False  False   False
# 3    False  False  False  False        False  False  False  False   False
# 4    False  False  False  False        False  False  False  False   False
# ..     ...    ...    ...    ...          ...    ...    ...    ...     ...
# 913  False  False  False   True        False  False  False  False   False
# 914  False  False  False   True        False  False  False  False   False
# 915  False  False  False   True        False  False  False  False   False
# 916  False  False  False   True        False  False  False  False   False
# 917  False  False  False   True        False  False  False  False   False
#
#      DEPRESSION  PENTE   CŒUR
# 0         False  False  False
# ...

# %%
# 16. Supprimer les données manquantes
df.dropna()
# Out:
#      AGE   SEXE  TDT    PAR  CHOLESTEROL  GAJ     ECG  FCMAX ANGINE  \
# 0     40  homme   AA  140.0        289.0    0  Normal    172    Non
# 1     49  femme  DNA  160.0        180.0    0  Normal    156    Non
# 2     37  homme   AA  130.0        283.0    0      ST     98    Non
# 3     48  femme  ASY  138.0        214.0    0  Normal    108    Oui
# 4     54  homme  DNA  150.0        195.0    0  Normal    122    Non
# ..   ...    ...  ...    ...          ...  ...     ...    ...    ...
# 908   63  homme  ASY  140.0        187.0    0     LVH    144    Oui
# 909   63  femme  ASY  124.0        197.0    0  Normal    136    Oui
# 910   41  homme   AA  120.0        157.0    0  Normal    182    Non
# 911   59  homme  ASY  164.0        176.0    1     LVH     90    Non
# 912   57  femme  ASY  140.0        241.0    0  Normal    123    Oui
#
#      DEPRESSION      PENTE  CŒUR
# 0           0.0  Ascendant     0
# 1           1.0       Plat     1
# 2           0.0  Ascendant     0
# ...

# %%
# 17. Recoder la variable sexe (masculin = 0 et féminin = 1)
df['SEXE'] = df['SEXE'].replace(['homme','femme'],[0,1])
df
# Out:
#      AGE  SEXE  TDT    PAR  CHOLESTEROL  GAJ     ECG  FCMAX ANGINE  \
# 0     40     0   AA  140.0        289.0    0  Normal    172    Non
# 1     49     1  DNA  160.0        180.0    0  Normal    156    Non
# 2     37     0   AA  130.0        283.0    0      ST     98    Non
# 3     48     1  ASY  138.0        214.0    0  Normal    108    Oui
# 4     54     0  DNA  150.0        195.0    0  Normal    122    Non
# ..   ...   ...  ...    ...          ...  ...     ...    ...    ...
# 913   45     0   AT    NaN        264.0    0  Normal    132    Non
# 914   68     0  ASY    NaN        193.0    1  Normal    141    Non
# 915   57     0  ASY    NaN        131.0    0  Normal    115    Oui
# 916   57     1   AA    NaN        236.0    0     LVH    174    Non
# 917   38     0  DNA    NaN        175.0    0  Normal    173    Non
#
#      DEPRESSION      PENTE  CŒUR
# 0           0.0  Ascendant     0
# 1           1.0       Plat     1
# 2           0.0  Ascendant     0
# ...

# %%
# 18. Supprimer la variable DEPRESSION et FCMAX
df=df.drop(['DEPRESSION','FCMAX'], axis=1)
df
# Out:
#      AGE  SEXE  TDT    PAR  CHOLESTEROL  GAJ     ECG ANGINE      PENTE  CŒUR
# 0     40     0   AA  140.0        289.0    0  Normal    Non  Ascendant     0
# 1     49     1  DNA  160.0        180.0    0  Normal    Non       Plat     1
# 2     37     0   AA  130.0        283.0    0      ST    Non  Ascendant     0
# 3     48     1  ASY  138.0        214.0    0  Normal    Oui       Plat     1
# 4     54     0  DNA  150.0        195.0    0  Normal    Non  Ascendant     0
# ..   ...   ...  ...    ...          ...  ...     ...    ...        ...   ...
# 913   45     0   AT    NaN        264.0    0  Normal    Non       Plat     1
# 914   68     0  ASY    NaN        193.0    1  Normal    Non       Plat     1
# 915   57     0  ASY    NaN        131.0    0  Normal    Oui       Plat     1
# 916   57     1   AA    NaN        236.0    0     LVH    Non       Plat     1
# 917   38     0  DNA    NaN        175.0    0  Normal    Non  Ascendant     0
#
# [918 rows x 10 columns]

# %%
# 19. Renommer la variable CHOLESTEROL en CHO
df.rename({'CHOLESTEROL':'CHO'}, axis=1)
# Out:
#      AGE  SEXE  TDT    PAR    CHO  GAJ     ECG ANGINE      PENTE  CŒUR
# 0     40     0   AA  140.0  289.0    0  Normal    Non  Ascendant     0
# 1     49     1  DNA  160.0  180.0    0  Normal    Non       Plat     1
# 2     37     0   AA  130.0  283.0    0      ST    Non  Ascendant     0
# 3     48     1  ASY  138.0  214.0    0  Normal    Oui       Plat     1
# 4     54     0  DNA  150.0  195.0    0  Normal    Non  Ascendant     0
# ..   ...   ...  ...    ...    ...  ...     ...    ...        ...   ...
# 913   45     0   AT    NaN  264.0    0  Normal    Non       Plat     1
# 914   68     0  ASY    NaN  193.0    1  Normal    Non       Plat     1
# 915   57     0  ASY    NaN  131.0    0  Normal    Oui       Plat     1
# 916   57     1   AA    NaN  236.0    0     LVH    Non       Plat     1
# 917   38     0  DNA    NaN  175.0    0  Normal    Non  Ascendant     0
#
# [918 rows x 10 columns]
